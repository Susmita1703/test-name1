# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv("imdb-top-1000.csv")
movies.groupby("Genre").sum()["Gross"]
#here teh syntax is       
#data name.groupby("column name").sum()["the column we want as output"]
# Out:
# Genre
# Action       3.263226e+10
# Adventure    9.496922e+09
# Animation    1.463147e+10
# Biography    8.276358e+09
# Comedy       1.566387e+10
# Crime        8.452632e+09
# Drama        3.540997e+10
# Family       4.391106e+08
# Fantasy      7.827267e+08
# Film-Noir    1.259105e+08
# Horror       1.034649e+09
# Mystery      1.256417e+09
# Thriller     1.755074e+07
# Western      5.822151e+07
# Name: Gross, dtype: float64

# %%
#if we want to know how many groups are formed
len(movies.groupby("Genre"))
# Out:
# 14

# %%
#if we want to know how namy rows are there in each group(value_counts)
movies.groupby("Genre").size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
#if we want to ist,2nd, nth value from a group
#suppose we want to find 1st movie from each group
ist=movies.groupby("Genre").first()
ist
nth=movies.groupby("Genre").nth(7)
nth
# Out:
#                  Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 28   The Silence of the Lambs          1991      118      Crime          8.6
# 29                  Star Wars          1977      121     Action          8.6
# 34                   Whiplash          2014      106      Drama          8.5
# 70              Mononoke-hime          1997      134  Animation          8.4
# 95                     Amélie          2001      122     Comedy          8.3
# 107                   Amadeus          1984      160  Biography          8.3
# 137                     Queen          2013      146  Adventure          8.2
# 714         The Lady Vanishes          1938       96    Mystery          7.8
# 844                 Halloween          1978       91     Horror          7.7
#
#                Director              Star1  No_of_Votes        Gross  \
# 28       Jonathan Demme       Jodie Foster      1270197  130742922.0
# ...

# %%
#when we want to know all details of any of group of my desire
Genre=movies.groupby("Genre")
Genre.get_group("Drama")
# Out:
#                         Series_Title Released_Year  Runtime  Genre  \
# 0           The Shawshank Redemption          1994      142  Drama
# 9                         Fight Club          1999      139  Drama
# 11                      Forrest Gump          1994      142  Drama
# 17   One Flew Over the Cuckoo's Nest          1975      133  Drama
# 20                   Soorarai Pottru          2020      153  Drama
# ..                               ...           ...      ...    ...
# 990                     Giù la testa          1971      157  Drama
# 993                           Blowup          1966      111  Drama
# 996                            Giant          1956      201  Drama
# 997            From Here to Eternity          1953      118  Drama
# 998                         Lifeboat          1944       97  Drama
#
#      IMDB_Rating                Director              Star1  No_of_Votes  \
# 0            9.3          Frank Darabont        Tim Robbins      2343110
# ...

# %%
Genre.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
Genre.sample()
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 60                Avengers: Infinity War          2018      149     Action
# 361                        Blood Diamond          2006      143  Adventure
# 651                                Shrek          2001       90  Animation
# 759                           Changeling          2008      141  Biography
# 192                   To Be or Not to Be          1942       99     Comedy
# 37                          The Departed          2006      151      Crime
# 734                       La vie d'Adèle          2013      180      Drama
# 698  Willy Wonka & the Chocolate Factory          1971      100     Family
# 321         Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 309                        The Third Man          1949      104  Film-Noir
# 844                            Halloween          1978       91     Horror
# ...

# %%
Genre.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
#if we want sum , min ,max  with diffrent columns of my choice
Genre.agg({"Runtime":"mean","No_of_Votes":"sum","Metascore":"min"})
# Out:
#               Runtime  No_of_Votes  Metascore
# Genre
# Action     129.046512     72282412       33.0
# Adventure  134.111111     22576163       41.0
# Animation   99.585366     21978630       61.0
# Biography  136.022727     24006844       48.0
# Comedy     112.129032     27620327       45.0
# Crime      126.392523     33533615       47.0
# Drama      124.737024     61367304       28.0
# Family     107.500000       551221       67.0
# Fantasy     85.000000       146222        NaN
# Film-Noir  104.000000       367215       94.0
# Horror     102.090909      3742556       46.0
# Mystery    119.083333      4203004       52.0
# Thriller   108.000000        27733       81.0
# Western    148.250000      1289665       69.0

# %%
#when we want min max or other function in my selected column
Genre.agg({"IMDB_Rating":["min","max"]})
#when we want groupby in more than one column
special=movies.groupby(["Director","Genre"])
special.agg({"IMDB_Rating":["max","min"]})
# Out:
#                               IMDB_Rating
#                                       max  min
# Director            Genre
# Aamir Khan          Drama             8.4  8.4
# Aaron Sorkin        Drama             7.8  7.8
# Abdellatif Kechiche Drama             7.7  7.7
# Abhishek Chaubey    Action            7.8  7.8
# Abhishek Kapoor     Drama             7.7  7.7
# ...                                   ...  ...
# Zaza Urushadze      Drama             8.2  8.2
# Zoya Akhtar         Comedy            8.1  8.1
#                     Drama             8.0  8.0
# Çagan Irmak         Drama             8.3  8.3
# Ömer Faruk Sorak    Adventure         8.0  8.0
#
# [749 rows x 2 columns]

# %%
#loops in group by
for group,data in Genre:
    print(data[data["IMDB_Rating"]==data["IMDB_Rating"].max()])
# Out:
#       Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 2  The Dark Knight          2008      152  Action          9.0
#
#             Director           Star1  No_of_Votes        Gross  Metascore
# 2  Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 21  Interstellar          2014      169  Adventure          8.6
#
#              Director                Star1  No_of_Votes        Gross  \
# 21  Christopher Nolan  Matthew McConaughey      1512360  188020017.0
#
#     Metascore
# 21       74.0
#                      Series_Title Released_Year  Runtime      Genre  \
# 23  Sen to Chihiro no kamikakushi          2001      125  Animation
#
#     IMDB_Rating        Director          Star1  No_of_Votes       Gross  \
# 23          8.6  Hayao Miyazaki  Daveigh Chase       651376  10055859.0
#
#     Metascore
# 23       96.0
# ...

# %%
# when we want only column name of a data
name_of_columns=movies.columns
name_of_columns
#when we want whole data of a column
data_of_a_column=movies["Series_Title"]
data_of_a_column

# %%
#Here we want mean of each group  
Genre["IMDB_Rating"].mean()
#here we add a new column ranking where is according  IMDB RATING
movies['ranking']=movies.groupby('Genre')['IMDB_Rating'].rank(ascending=False)
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
df = pd.DataFrame(columns=movies.columns)
df
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore, ranking]
# Index: []

# %%
import pandas as pd

# Assuming 'movies' is your original DataFrame and 'genres' is a groupby object

df = pd.DataFrame(columns=movies.columns)
for group, data in Genre:
    # Find the row with the maximum IMDB_Rating in each group and append it to the 'df' DataFrame
    max_rating_row = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    print(pd.DataFrame(max_rating_row,columns=df))

# Now 'df' contains the rows with the maximum IMDB_Rating from each group
# Out:
# Empty DataFrame
# Columns: []
# Index: [2]
# Empty DataFrame
# Columns: []
# Index: [21]
# Empty DataFrame
# Columns: []
# Index: [23]
# Empty DataFrame
# Columns: []
# Index: [7]
# Empty DataFrame
# Columns: []
# Index: [19, 26]
# Empty DataFrame
# Columns: []
# Index: [1]
# Empty DataFrame
# Columns: []
# Index: [0]
# Empty DataFrame
# Columns: []
# Index: [688, 698]
# Empty DataFrame
# Columns: []
# Index: [321]
# Empty DataFrame
# Columns: []
# Index: [309]
# Empty DataFrame
# Columns: []
# Index: [49]
# Empty DataFrame
# Columns: []
# Index: [69, 81]
# Empty DataFrame
# Columns: []
# Index: [700]
# Empty DataFrame
# Columns: []
# Index: [12]

# %%
b=[]
for i,j in Genre:
    b.append((i,Genre.get_group(i).Series_Title.str.startswith('A').sum()))
pd.DataFrame(b,columns=["Genre","start with A"])
# Out:
#         Genre  start with A
# 0      Action            10
# 1   Adventure             2
# 2   Animation             2
# 3   Biography             9
# 4      Comedy            14
# 5       Crime             4
# 6       Drama            21
# 7      Family             0
# 8     Fantasy             0
# 9   Film-Noir             0
# 10     Horror             1
# 11    Mystery             0
# 12   Thriller             0
# 13    Western             0

# %%
b=[]
for i,j in Genre:
    b.append((i,Genre.get_group(i).Series_Title.str.startswith('A').sum()))
b
# Out:
# [('Action', 10),
#  ('Adventure', 2),
#  ('Animation', 2),
#  ('Biography', 9),
#  ('Comedy', 14),
#  ('Crime', 4),
#  ('Drama', 21),
#  ('Family', 0),
#  ('Fantasy', 0),
#  ('Film-Noir', 0),
#  ('Horror', 1),
#  ('Mystery', 0),
#  ('Thriller', 0),
#  ('Western', 0)]

# %%
import pandas as pd

# Assuming 'movies' is your original DataFrame and 'genres' is a groupby object

# Create an empty DataFrame with the same columns as 'movies'
df = pd.DataFrame(columns=movies.columns)

# Iterate over groups and data
for group, data in Genre:
    # Find the row with the maximum IMDB_Rating in each group and append it to the 'df' DataFrame
    max_rating_row = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    u=[]
    u.append(group)
    df = pd.concat([df, max_rating_row])
df


# Now 'df' contains the rows with the maximum IMDB_Rating from each group
# Out:
#                             Series_Title Released_Year Runtime      Genre  \
# 2                        The Dark Knight          2008     152     Action
# 21                          Interstellar          2014     169  Adventure
# 23         Sen to Chihiro no kamikakushi          2001     125  Animation
# 7                       Schindler's List          1993     195  Biography
# 19                          Gisaengchung          2019     132     Comedy
# 26                       La vita è bella          1997     116     Comedy
# 1                          The Godfather          1972     175      Crime
# 0               The Shawshank Redemption          1994     142      Drama
# 688           E.T. the Extra-Terrestrial          1982     115     Family
# 698  Willy Wonka & the Chocolate Factory          1971     100     Family
# 321         Das Cabinet des Dr. Caligari          1920      76    Fantasy
# 309                        The Third Man          1949     104  Film-Noir
# ...
